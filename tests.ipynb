# %% [markdown]
# <font size='6'><b>Scalable Approximate Algorithms for Optimal Transport Linear Models: Tests</b></font>

# %%
from otlm import tests

# %% [markdown]
# # Test the unpenalized OTLM weight update

# %%
tests.test_prox_kl_nnsx_mm() # test the original derived function
tests.test_otlm_fix() # test the implementation in the package
# Out:
# Toy Example Data:
# X =
#  [[0.6488135  0.81518937 0.70276338]
#  [0.64488318 0.5236548  0.74589411]
#  [0.53758721 0.991773   1.06366276]
#  [0.48344152 0.89172504 0.62889492]]
# y = [0.5 1.  2.  1.5]
#
# === Solve with MM Algorithm (prox_kl_nnsx_mm) ===
# MM Iteration 1: w = [0.49028416 0.52908952 0.53354881], L(w) = 0.481454
# MM Iteration 2: w = [0.46229319 0.53776503 0.54700975], L(w) = 0.476171
# MM Iteration 3: w = [0.43568434 0.54573482 0.56007297], L(w) = 0.471203
# MM Iteration 4: w = [0.41042225 0.55302375 0.57274431], L(w) = 0.466535
# MM Iteration 5: w = [0.38646664 0.55965881 0.58503103], L(w) = 0.462149
# MM Iteration 6: w = [0.36377352 0.56566841 0.59694157], L(w) = 0.458031
# MM Iteration 7: w = [0.34229633 0.57108193 0.60848516], L(w) = 0.454163
# MM Iteration 8: w = [0.32198678 0.57592921 0.61967164], L(w) = 0.450532
# MM Iteration 9: w = [0.30279566 0.58024019 0.63051125], L(w) = 0.447123
# MM Iteration 10: w = [0.28467345 0.58404458 0.64101444], L(w) = 0.443922
# ...

# %% [markdown]
# # Test the L1-penalized OTLM weight update

# %%
tests.test_prox_kl_nnsx_l1_mm() # test the original derived function
tests.test_otlm_l1() # test the implementation in the package
# Out:
# Toy Data:
# X =
#  [[1.09762701 1.43037873 1.20552675]
#  [1.08976637 0.8473096  1.29178823]
#  [0.87517442 1.783546   1.92732552]
#  [0.76688304 1.58345008 1.05778984]
#  [1.13608912 1.85119328 0.14207212]]
# y =
#  [0.1742586  0.04043679 1.66523969 1.5563135  1.7400243 ]
# epsilon = 1.0 , alpha = 0.1
# Initial w = [1. 1. 1.]
# ---------------------------------------------------
#
# Solving ProxNNSX L1 via MM Algorithm...
#
# [MM] Iter 0: w = [1. 1. 1.], L_L1 = 22.128942
# [MM] Iter 1: w = [0.12334826 0.19304793 0.1119171 ], L_L1 = 2.406831
# [MM] Iter 2: w = [0.10221336 0.24763161 0.08613867], L_L1 = 2.255263
# [MM] Iter 3: w = [0.08018706 0.29750997 0.06390054], L_L1 = 2.128433
# [MM] Iter 4: w = [0.06025798 0.33913312 0.04600533], L_L1 = 2.029735
# [MM] Iter 5: w = [0.04386697 0.3715841  0.03238448], L_L1 = 1.956721
# [MM] Iter 6: w = [0.03122536 0.39570122 0.0224328 ], L_L1 = 1.904475
# [MM] Iter 7: w = [0.02188506 0.41305173 0.01536698], L_L1 = 1.867876
# ...

# %% [markdown]
# # Test the L2-penalized OTLM weight update

# %%
tests.test_prox_kl_nnsx_l2_mm() # test the original derived function
tests.test_otlm_l2() # test the implementation in the package
# Out:
# === TOY EXAMPLE DATA ===
# X =
#  [[0.6488135  0.81518937 0.70276338]
#  [0.64488318 0.5236548  0.74589411]
#  [0.53758721 0.991773   1.06366276]
#  [0.48344152 0.89172504 0.62889492]
#  [0.66804456 1.02559664 0.17103606]]
# y = [0.1871293  0.1202184  0.93261985 0.87815675 0.97001215]
# eps = 1.0 alpha = 0.5
#
# === SOLVING WITH MM ALGORITHM ===
# MM Iter = 0, w = [1. 1. 1.], L_L2(w) = 9.424666
# MM Iter = 1, w = [0.19623022 0.24421934 0.18459229], L_L2(w) = 0.803772
# MM Iter = 2, w = [0.18197792 0.27892279 0.16265177], L_L2(w) = 0.772120
# MM Iter = 3, w = [0.16677972 0.31157994 0.14280133], L_L2(w) = 0.744465
# MM Iter = 4, w = [0.15148948 0.3415782  0.12508715], L_L2(w) = 0.720724
# MM Iter = 5, w = [0.13670733 0.36863737 0.10944804], L_L2(w) = 0.700588
# MM Iter = 6, w = [0.12280759 0.39272934 0.09574748], L_L2(w) = 0.683633
# MM Iter = 7, w = [0.10998831 0.41399071 0.08380642], L_L2(w) = 0.669405
# MM Iter = 8, w = [0.09832299 0.43264955 0.07342964], L_L2(w) = 0.657473
# ...
